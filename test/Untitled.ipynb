# %%
h <- c(1, 2, 3, 4, 5, 6)

# %%
M <- c("A", "B", "C", "D", "E", "F")

# %%
barplot(h,
    names.arg = M, xlab = "X", ylab = "Y",
    col = "#00cec9", main = "Chart", border = "#fdcb6e"
)
# Out:
# Plot with title “Chart”
